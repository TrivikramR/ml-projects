# %% [markdown]
# # Heart Disease training dataset from keggle

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_heart = pd.read_csv('heart.csv')
df_heart
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
df_heart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
df_heart.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
# 1. Target distribution
print(df_heart['target'].value_counts())
print(df_heart['target'].value_counts(normalize=True).round(3))

# 2. Correlation with target
print(df_heart.corr()['target'].sort_values(ascending=False))
# Out:
# target
# 1    526
# 0    499
# Name: count, dtype: int64
# target
# 1    0.513
# 0    0.487
# Name: proportion, dtype: float64
# target      1.000000
# cp          0.434854
# thalach     0.422895
# slope       0.345512
# restecg     0.134468
# fbs        -0.041164
# chol       -0.099966
# trestbps   -0.138772
# age        -0.229324
# sex        -0.279501
# thal       -0.337838
# ca         -0.382085
# exang      -0.438029
# oldpeak    -0.438441
# Name: target, dtype: float64

# %%
(df_heart['target']==1).sum() # Total number of people have heart desease
# Out:
# 526

# %%
(((df_heart['target']==1).sum()/len(df_heart.target)) *100).round(2)
# Out:
# 51.32

# %%
(df_heart['target']==0).sum()
# Out:
# 499

# %%
(((df_heart['target']==0).sum()/len(df_heart.target)) *100).round(2)
# Out:
# 48.68

# %%
df_heart.duplicated().sum()
# Out:
# 723

# %%
df_heart[df_heart.duplicated()].head(10)
# Out:
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 15   34    0   1       118   210    0        1      192      0      0.7
# 31   50    0   1       120   244    0        1      162      0      1.1
# 43   46    1   0       120   249    0        0      144      0      0.8
# 55   55    1   0       140   217    0        1      111      1      5.6
# 61   66    0   2       146   278    0        0      152      0      0.0
# 64   29    1   1       130   204    0        0      202      0      0.0
# 79   52    1   1       134   201    0        1      158      0      0.8
# 82   46    1   2       150   231    0        1      147      0      3.6
# 83   38    1   2       138   175    0        1      173      0      0.0
# 84   37    0   2       120   215    0        1      170      0      0.0
#
#     slope  ca  thal  target
# 15      2   0     2       1
# 31      2   0     2       1
# 43      2   0     3       0
# 55      0   0     3       0
# 61      1   1     2       1
# ...

# %%
df_heart[df_heart.duplicated(keep=False)].sort_values(
    by=df_heart.columns.tolist()
).head(20)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 60    29    1   1       130   204    0        0      202      0      0.0
# 64    29    1   1       130   204    0        0      202      0      0.0
# 118   29    1   1       130   204    0        0      202      0      0.0
# 668   29    1   1       130   204    0        0      202      0      0.0
# 12    34    0   1       118   210    0        1      192      0      0.7
# 15    34    0   1       118   210    0        1      192      0      0.7
# 779   34    0   1       118   210    0        1      192      0      0.7
# 143   34    1   3       118   182    0        0      174      0      0.0
# 201   34    1   3       118   182    0        0      174      0      0.0
# 572   34    1   3       118   182    0        0      174      0      0.0
# 256   35    0   0       138   183    0        1      182      0      1.4
# 501   35    0   0       138   183    0        1      182      0      1.4
# ...

# %%
df_heart_clean = df_heart.drop_duplicates()

# %%
df_heart_clean
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     52    1   0       125   212    0        1      168      0      1.0
# 1     53    1   0       140   203    1        0      155      1      3.1
# 2     70    1   0       145   174    0        1      125      1      2.6
# 3     61    1   0       148   203    0        1      161      0      0.0
# 4     62    0   0       138   294    1        1      106      0      1.9
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 723   68    0   2       120   211    0        0      115      0      1.5
# 733   44    0   2       108   141    0        1      175      0      0.6
# 739   52    1   0       128   255    0        1      161      1      0.0
# 843   59    1   3       160   273    0        0      125      0      0.0
# 878   54    1   0       120   188    0        1      113      0      1.4
#
#      slope  ca  thal  target
# 0        2   2     3       0
# 1        0   0     3       0
# ...

# %%
df_heart_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 302 entries, 0 to 878
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       302 non-null    int64
#  1   sex       302 non-null    int64
#  2   cp        302 non-null    int64
#  3   trestbps  302 non-null    int64
#  4   chol      302 non-null    int64
#  5   fbs       302 non-null    int64
#  6   restecg   302 non-null    int64
#  7   thalach   302 non-null    int64
#  8   exang     302 non-null    int64
#  9   oldpeak   302 non-null    float64
#  10  slope     302 non-null    int64
#  11  ca        302 non-null    int64
#  12  thal      302 non-null    int64
#  13  target    302 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 35.4 KB

# %%
df_heart_clean.describe()
# Out:
#              age         sex          cp    trestbps        chol         fbs  \
# count  302.00000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean    54.42053    0.682119    0.963576  131.602649  246.500000    0.149007
# std      9.04797    0.466426    1.032044   17.563394   51.753489    0.356686
# min     29.00000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     48.00000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.50000    1.000000    1.000000  130.000000  240.500000    0.000000
# 75%     61.00000    1.000000    2.000000  140.000000  274.750000    0.000000
# max     77.00000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  302.000000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean     0.526490  149.569536    0.327815    1.043046    1.397351    0.718543
# ...

# %%
(df_heart_clean['target']==1).sum()
# Out:
# 164

# %%
(df_heart_clean['target']==0).sum()
# Out:
# 138

# %%
df_heart_clean['target'].value_counts()
# Out:
# target
# 1    164
# 0    138
# Name: count, dtype: int64

# %%
((df_heart_clean['target'].value_counts(normalize=True))*100).round(3)
# Out:
# target
# 1    54.305
# 0    45.695
# Name: proportion, dtype: float64

# %%
print(df_heart_clean.corr()['target'].sort_values(ascending=False))
# Out:
# target      1.000000
# cp          0.432080
# thalach     0.419955
# slope       0.343940
# restecg     0.134874
# fbs        -0.026826
# chol       -0.081437
# trestbps   -0.146269
# age        -0.221476
# sex        -0.283609
# thal       -0.343101
# ca         -0.408992
# oldpeak    -0.429146
# exang      -0.435601
# Name: target, dtype: float64
